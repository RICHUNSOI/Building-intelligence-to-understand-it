# %%
import sys
print(sys.executable)
# Out:
# c:\Users\ljs44\anaconda3\envs\py311\python.exe

# %%
!"{sys.executable}" -m pip install torch numpy

# %%
import torch
print(torch.__version__)
# Out:
# 2.13.0+cpu

# %%
import webbrowser

url = "https://www.youtube.com/watch?v=kCc8FmEb1nY"
webbrowser.open(url)
# Out:
# True
